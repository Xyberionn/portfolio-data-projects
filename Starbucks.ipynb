# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm

# %%
sns.set_style("darkgrid")
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r',
# ...

# %%
df = pd.read_csv(r'/Users/ogulcan/Desktop/Projects/starbucks.csv',index_col=0)
df
# Out:
#                                      item  calories   fat  carb  fiber  \
# 1                            8-Grain Roll       350   8.0    67      5
# 2                       Apple Bran Muffin       350   9.0    64      7
# 3                           Apple Fritter       420  20.0    59      0
# 4                         Banana Nut Loaf       490  19.0    75      4
# 5             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 73        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 74                Turkey & Swiss Sandwich       390  13.0    36      2
# 75             Greek Yogurt Honey Parfait       300  12.0    44      0
# 76         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 1        10    bakery
# 2         6    bakery
# 3         5    bakery
# ...

# %%
df.describe()
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
df["item"].unique
df["type"].unique()
# Out:
# array(['bakery', 'bistro box', 'petite', 'hot breakfast', 'salad',
#        'sandwich', 'parfait'], dtype=object)

# %%
df.groupby("type")["item"].count()
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %%
df.groupby("type")["item"].count().plot(kind="line", color="blue", figsize=(10, 5), title="Types of Items")
plt.xlabel("Types")
plt.text(0, 50, "Types of Items", bbox=dict(facecolor='Green', alpha=0.5))
plt.show()

# %%
colors = cm.get_cmap("Set1").colors
df.groupby("type")["item"].count().plot(kind="bar", color=colors, figsize=(10, 5), title="Types of Items")
plt.xlabel("Types")
plt.text(0, 50, "Types of Items", bbox=dict(facecolor='Green', alpha=0.5))
plt.show()
# Out:
# /var/folders/jl/m9thb3l97_14j8thlylmz5v40000gn/T/ipykernel_33225/1272323440.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("Set1").colors

# %%
df.groupby("type")["calories"].mean().plot(kind="bar", color=colors, figsize=(10, 5), title="Calories by Type")
plt.xlabel("Types")
plt.show()

# %%
df.groupby("type")["protein"].mean().plot(kind="bar", color=colors, figsize=(10, 5), title="Protein by Type")
plt.xlabel("Types")
plt.show()

# %%
df.groupby("type")["carb"].mean().plot(kind="bar", color=colors, figsize=(10, 5), title="Protein by Type")
plt.xlabel("Types")
plt.show()

# %%
df.groupby("type")["fiber"].mean().plot(kind="bar", color=colors, figsize=(10, 5), title="Protein by Type")
plt.xlabel("Types")
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#           calories       fat      carb     fiber   protein
# calories  1.000000  0.758682  0.674999  0.260645  0.410398
# fat       0.758682  1.000000  0.144547 -0.028549  0.223470
# carb      0.674999  0.144547  1.000000  0.213044 -0.050789
# fiber     0.260645 -0.028549  0.213044  1.000000  0.488564
# protein   0.410398  0.223470 -0.050789  0.488564  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="twilight_shifted", center=0)
# Out:
# <Axes: >

# %%
plt.title("Colories and Fat")
sns.scatterplot(x="calories", y="fat", data=df, hue="type",s=30, palette=colors)
# Out:
# <Axes: title={'center': 'Colories and Fat'}, xlabel='calories', ylabel='fat'>

# %%
sns.displot(x="calories",data = df , color = "red" , kde = True)
plt.title("Calories Distribution")
plt.show()

# %%
sns.displot(x="protein",data = df , color = "purple" , kde = True)
plt.title("Protein Distribution")
plt.show()

# %%
sns.displot(x="fat",data = df , color = "orange" , kde = True)
plt.title("Fat Distribution")
plt.show()

# %%
sns.displot(x="carb",data = df , color = "blue" , kde = True)
plt.title("Carb Distribution")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x = df[["fat","calories","protein","carb","fiber"]]
y= df["type"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_prediction = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_prediction)
print(accuracy)
# Out:
# 0.6875

# %%
prediction = model.predict([[300, 3, 60, 1, 4]])
print(prediction)
# Out:
# ['bistro box']
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20, 10))
plot_tree(model, feature_names=x.columns, class_names=model.classes_, filled=True)
plt.title("Decision Tree")
plt.show()
